# %% [markdown]
# <a href="https://colab.research.google.com/github/StephenSzulc/4AI3-Project/blob/visualization/4AI3_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import keras library to load dataset
import keras
from keras.datasets import cifar10
from keras.datasets.cifar10 import load_data

# import matplotlib and seaborn libraries to visualize data
import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns

# create training and test sets for the cifar10 dataset
(x_train_data, y_train_data) , (x_test_data, y_test_data) = cifar10.load_data()

# plot the labels in count plots
fig, axs = plt.subplots(1,2, figsize=(15,5))

sns.countplot(y_test_data.ravel(), ax=axs[1])
sns.countplot(y_train_data.ravel(), ax=axs[0])

axs[0].set_xlabel('Classes')
axs[1].set_xlabel('Classes')

axs[0].set_title('Training Data')
axs[1].set_title('Testing Data')
# Out:
# Train (50000, 32, 32, 3) (50000, 1)
# Test (10000, 32, 32, 3) (10000, 1)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Testing Data')

# %%
# print the shape to see how our X and y variables are split
print('Train', x_train_data.shape, y_train_data.shape)
print('Test', x_test_data.shape, y_test_data.shape)
# Out:
# Train (50000, 32, 32, 3) (50000, 1)
# Test (10000, 32, 32, 3) (10000, 1)

# %%
# plot first 49 images from the training dataset
plt.figure(figsize=(25, 25))
for i in range(49):
  plt.subplot(7, 7, 1 + i)
  plt.axis('off')
  plt.imshow(x_train_data[i])
plt.show()
